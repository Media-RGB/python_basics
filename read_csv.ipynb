# %% [markdown]
# ### Usefull short cut in jupyter
#
# - Shift + Enter : 'execute current line'
# - B.B : 'create empty line above'
# - A.A : 'bellow'
#
# To write doc text change code to markdown
# ![image.png](attachment:c5f772fb-7b35-4435-af33-87cef7b1ce15.png)

# %%
import pandas as pd

# %%
df = pd.read_csv("wind_sun_reg_3h.csv", sep=";")

# %%
df
# Out:
#                              Date  Code INSEE région  \
# 0       2016-08-15T11:00:00+02:00                 93
# 1       2016-08-15T11:00:00+02:00                 94
# 2       2016-08-15T11:00:00+02:00                 75
# 3       2016-08-15T11:00:00+02:00                 44
# 4       2016-08-15T11:00:00+02:00                 32
# ...                           ...                ...
# 333002  2024-10-03T20:00:00+02:00                 76
# 333003  2024-10-03T20:00:00+02:00                 75
# 333004  2024-10-03T20:00:00+02:00                 93
# 333005  2024-10-03T23:00:00+02:00                 24
# 333006  2024-10-03T23:00:00+02:00                 32
#
#                             Région  Vitesse du vent à 100m (m/s)  \
# 0       Provence-Alpes-Côte d'Azur                          4.51
# 1                            Corse                          2.63
# 2               Nouvelle-Aquitaine                          3.58
# ...

# %%
df.head() # show the 5 first lines
# Out:
#                         Date  Code INSEE région                      Région  \
# 0  2016-08-15T11:00:00+02:00                 93  Provence-Alpes-Côte d'Azur
# 1  2016-08-15T11:00:00+02:00                 94                       Corse
# 2  2016-08-15T11:00:00+02:00                 75          Nouvelle-Aquitaine
# 3  2016-08-15T11:00:00+02:00                 44                   Grand Est
# 4  2016-08-15T11:00:00+02:00                 32             Hauts-de-France
#
#    Vitesse du vent à 100m (m/s)  Rayonnement solaire global (W/m2)
# 0                          4.51                             417.94
# 1                          2.63                             449.81
# 2                          3.58                             339.16
# 3                          4.32                             387.79
# 4                          5.27                             365.57

# %%
df.describe()
# Out:
#        Code INSEE région  Vitesse du vent à 100m (m/s)  \
# count      333007.000000                 333007.000000
# mean           53.307570                      5.771187
# std            27.291535                      1.772308
# min            11.000000                      1.380000
# 25%            28.000000                      4.500000
# 50%            52.000000                      5.550000
# 75%            76.000000                      6.780000
# max            94.000000                     16.550000
#
#        Rayonnement solaire global (W/m2)
# count                      333007.000000
# mean                          159.922772
# std                           215.202298
# min                             0.000000
# 25%                             0.010000
# 50%                            33.020000
# 75%                           287.980000
# max                           899.150000

# %%
json_output = df[:10].to_json(orient='records', indent=4) # que les 10 premiéres ligne

# %%
print(json_output)
# Out:
# [
#     {
#         "Date":"2016-08-15T11:00:00+02:00",
#         "Code INSEE r\u00e9gion":93,
#         "R\u00e9gion":"Provence-Alpes-C\u00f4te d'Azur",
#         "Vitesse du vent \u00e0 100m (m\/s)":4.51,
#         "Rayonnement solaire global (W\/m2)":417.94
#     },
#     {
#         "Date":"2016-08-15T11:00:00+02:00",
#         "Code INSEE r\u00e9gion":94,
#         "R\u00e9gion":"Corse",
#         "Vitesse du vent \u00e0 100m (m\/s)":2.63,
#         "Rayonnement solaire global (W\/m2)":449.81
#     },
#     {
#         "Date":"2016-08-15T11:00:00+02:00",
#         "Code INSEE r\u00e9gion":75,
#         "R\u00e9gion":"Nouvelle-Aquitaine",
#         "Vitesse du vent \u00e0 100m (m\/s)":3.58,
#         "Rayonnement solaire global (W\/m2)":339.16
#     },
#     {
#         "Date":"2016-08-15T11:00:00+02:00",
#         "Code INSEE r\u00e9gion":44,
#         "R\u00e9gion":"Grand Est",
#         "Vitesse du vent \u00e0 100m (m\/s)":4.32,
# ...
